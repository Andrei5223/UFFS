# %% [markdown]
# #Classes  em Python
#
# Classes permitem agregar dados e funcionalidades, ou seja,  criar novos tipos de dados.
#
# Exemplo:

# %%
#definindo uma classe
class Car:
  brand = None
  model = None
  year = None

# %%
#criando um objeto (instância) da classe Car
mycar1 = Car()  

mycar1.brand = 'Peugeot'
mycar1.model = 308
mycar1.year = 2015

print("brand: ", mycar1.brand)
print("model:", mycar1.model)
print("year:", mycar1.year)
# Out:
# brand:  Peugeot
# model: 308
# year: 2015

# %%
#criando outra instância da classe Car
mycar2 = Car()  

mycar2.brand='chevrolet'
mycar2.model='opala'
mycar2.year='1978'

print("brand: ", mycar2.brand)
print("model:", mycar2.model)
print("year:", mycar2.year)
# Out:
# brand:  chevrolet
# model: opala
# year: 1978

# %% [markdown]
# ##Atividades

# %% [markdown]
# **1**- Instancie dois novos carros e os **imprima**:

# %%
mycar3 = Car()

mycar3.brand = "Honda"
mycar3.model = "Civic"
mycar3.year = 2005

mycar4 = Car()
mycar4.brand = "BMW"
mycar4.model = "algum ai"
mycar4.year = 2015

print(mycar3.brand, mycar3.model, mycar3.year)
print(mycar4.brand, mycar4.model, mycar4.year)
# Out:
# Honda Civic 2005
# BMW algum ai 2015

# %% [markdown]
# **2** - Crie uma classe para gerar um cadastro de um usuário (nome, cpf, senha, data_nascimento) e instancie 2 usuários.

# %%
class ficha:
  nome = None
  cpf = None
  senha = None
  data = None

usuario1 = ficha()
usuario1.nome = input("Digite seu nome: ")
usuario1.cpf = input("Digite seu CPF: ")
usuario1.senha = input("Digite uma senha: ")
usuario1.data = input("Digite sua data de nascimento: ")

usuario2 = ficha()
usuario2.nome = input("Digite seu nome: ")
usuario2.cpf = input("Digite seu CPF: ")
usuario2.senha = input("Digite uma senha: ")
usuario2.data = input("Digite sua data de nascimento: ")

print(usuario1.nome, usuario1.cpf, usuario1.senha, usuario1.data)
print(usuario2.nome, usuario2.cpf, usuario2.senha, usuario2.data)
# Out:
# Digite seu nome: Andrei
# Digite seu CPF: 04785461274
# Digite uma senha: 74568
# Digite sua data de nascimento: 16062001
# Digite seu nome: fsfse
# Digite seu CPF: 684564
# Digite uma senha: fsrg8745sd1fs7f647fsdf3
# Digite sua data de nascimento: 07052004
# Andrei 04785461274 74568 16062001
# fsfse 684564 fsrg8745sd1fs7f647fsdf3 07052004

# %% [markdown]
# **3** - Crie uma *classe* para cadastrar produtos com nome, descrição, preço e quantidade em estoque.

# %%
class produto:
  nome = None
  descricao = None
  preco = None
  quant = None

# %% [markdown]
# #Criando uma lista com estruturas

# %%
class Conta:
  numero = None
  titular = None
  saldo = 0

vetor = []
for i in range(2):
  c = Conta()
  c.numero = input("\nNúmero: ")
  c.titular = input("Titular: ")
  c.saldo = input("Saldo: ")
  vetor.append(c)

#exibindo todas as contas
print("\nRelatório de contas:")
for i in range(2):
  print(" id: ", vetor[i].numero, " cliente: ", vetor[i].titular, " saldo: ", vetor[i].saldo)

#exibindo uma conta específica
print("\nConta armazenada no índice 1:")
print(f'O cliente {vetor[1].titular} possui saldo de R$ {vetor[1].saldo}')

# %% [markdown]
# ##Atividades
# **4** - Crie um **vetor** com 3 carros (classe Car), faça a leitura dos dados e, ao final, imprima os dados dos 3 carros.

# %%
carros = []
class carro:
  marca = None
  modelo = None
  ano = None

carro = carros()
carro.marca = "wv"
carro.modelo = "Gol"
carro.ano = 2004

carro1 = carros()
carro1.marca = "Honda"
carro1.modelo = "Civic"
carro1.ano = 2009

carro2 = carros()
carro1.marca = "BMW"
carro1.modelo = "X7"
carro1.ano = 2020

# %% [markdown]
# **5** - Implemente uma função chamada **adicionaConta** capaz de adicionar um novo cliente (carregado com dados fornecidos pelo usuário) ao vetor.

# %% [markdown]
# **6** - Implemente uma função chamada **exibeContas** capaz de imprimir todos os clientes com saldo maior ou igual a que N reais. O valor de N deve ser passado por parâmetro para a função.

# %% [markdown]
# #Extra: Inicializando valores na classe
#
# É possível inicializar os valores das variáveis da classe no momento da instanciação. Para isso, definimos dentro da classe uma função com nome padrão de `__init__`. Esta função recebe os valores a serem usados na inicialização e atribui cada um à respectiva variável da classe.
#
# A palavra reservada `self` é  usada para mostrar quais variáveis pertencem a classe.

# %%
class Car():
  def __init__(self, model, color, company, speed_limit):
    self.color = color
    self.company = company
    self.speed_limit = speed_limit
    self.model = model

# %%
fusca = Car(input("Modelo: "), input("Cor: "), "vw", 60)
audi = Car("A6", "vermelho", "audi", 280)

# %%
print(fusca.color)
