# %% [markdown]
# # Comando de repetição While - continuação
#
# As estruturas de repetição são utilizadas para descrever situações nas quais os passos de uma computação são repetidos diversas vezes.
#
# A quantidade de repetições depende do valor produzido pela avaliação de uma expressão condicional.
#
# ```python
# while expressão:
#     # bloco de comandos
# ```
#
# O `while` continua a repetir o bloco de comandos até que a condição se torne False.

# %% [markdown]
# ##Repetição com contador
#
# São repetições onde o bloco de comandos deve ser executado um número pré-definido de vezes.
#
# Este número de iterações pode ser fixo, determinado pelo enunciado do próprio problema, ou pode ser deixado em aberto, para que o usuário defina-o no início da execução do programa.

# %%
#número fixo de iterações, definido no código-fonte do programa: 

i = 1    
while i <= 7:    #repete sempre 7 vezes
  print(i)
  i = i + 1 #incremento do contador

# %%
#número variável de iterações, definido pelo usuário antes do início do while:

limite = int(input("Quantas vezes a repetição deve ocorrer? "))
i = 1     
while i <= limite:    #repete até o limite definido pelo usuário
  print(i)
  i = i + 1

# %% [markdown]
# ###Atividades
#
# **AT1** - Escreva um programa que utilize o comando while para ler 10 valores e contar quantos destes valores são negativos. Apresentar esta informação ao final do programa.
#
# Exemplo de entrada:
#
# 5, -6, -1, 0, 90, -45, 10, -8, 23, 11
#
# Saída: Foram digitados 4 valores negativos

# %%
i = 1
resp = 0
while i <= 10:
  n = int(input(f'Digite o valor inteiro número {i}: '))
  if n < 0:
    resp += 1
  i += 1
print(f'Foram digitados {resp} valores negativos.')
# Out:
# Digite o valor inteiro número 1: 4578
# Digite o valor inteiro número 2: -4
# Digite o valor inteiro número 3: -1
# Digite o valor inteiro número 4: -4
# Digite o valor inteiro número 5: -5
# Digite o valor inteiro número 6: 8
# Digite o valor inteiro número 7: 7
# Digite o valor inteiro número 8: 58
# Digite o valor inteiro número 9: -4
# Digite o valor inteiro número 10: -3
# Foram digitados 6 valores negativos.

# %% [markdown]
# **AT2** - Repita o exercício anterior, porém, ao invés de 10 devem ser lidos N valores. N será fornecido pelo usuário no início do programa.
#
# Exemplo de entrada:
#
# Quantos valores serão digitados?  3
#
# -1
#
# 5
#
# -9
#
# Saída: Foram digitados 2 valores negativos

# %%
v = int(input('Quantos valores serão digitados? '))
i = 1
resp = 0
while i <= v:
  n = int(input(f'Digite o valor inteiro número {i}: '))
  if n < 0:
    resp += 1
  i += 1
print(f'Foram digitados {resp} valores negativos.')
# Out:
# Quantos valores serão digitados? 7
# Digite o valor inteiro número 1: -7
# Digite o valor inteiro número 2: -5
# Digite o valor inteiro número 3: 4
# Digite o valor inteiro número 4: -45
# Digite o valor inteiro número 5: 4
# Digite o valor inteiro número 6: -6
# Digite o valor inteiro número 7: 4
# Foram digitados 4 valores negativos.

# %% [markdown]
# **AT3** - Faça um algoritmo que leia um valor inteiro fornecido pelo usuário e, usando while, calcule a soma de seus 10 sucessores. A soma deve ser exibida ao final do programa.
#
# Exemplo de entrada: 11
#
# Saída: 165

# %%
n = int(input('Insira um valor: ')) + 1
soma = 0
rep = 1
while rep <= 10:
  soma = soma + n
  n += 1
  rep += 1
print(f"A soma de seus 10 sucessores é: {soma}")
# Out:
# Insira um valor: 11
# A soma de seus 10 sucessores é: 165

# %% [markdown]
# **AT4** - Repita o exercício anterior, porém, pergunte também ao usuário quantos sucessores ele deseja somar.
#
# Exemplo de entrada:
#
# Qual o valor inicial? 4
#
# Quantos sucessores você deseja somar? 5
#
# Saída: 35

# %%
n = int(input('Insira um valor: ')) + 1
soma = 0
nrep = int(input('Insira o número de sucessores que deseja somar: '))
rep = 1
while rep <= nrep:
  soma = soma + n
  n += 1
  rep += 1
print(f"A soma de seus 10 sucessores é: {soma}")
# Out:
# Insira um valor: 2
# Insira o número de sucessores que deseja somar: 3
# A soma de seus 10 sucessores é: 12

# %% [markdown]
# **AT5** - Em um parque, uma árvore da espécie A tem 1,50m e cresce 2 cm por ano. Já uma árvore da espécie B tem 1,10m  e  cresce  3 cm  por  ano.  Faça  um  programa  que calcule quantos anos serão necessários para que a árvore B atinja a altura  da árvore A.

# %%
a = 150
b = 110
ano = 0
while a > b:
  a += 2
  b += 3
  ano += 1
print(f'A árvore B demorará {ano} anos para alcançar a altura da A.')
# Out:
# A árvore B demorará 40 anos para alcançar a altura da A.

# %% [markdown]
# **AT6** - Faça uma repetição de 0 a 100. Cada valor do contador deve ser impresso, exceto os múltiplos de 5; quando um múltiplo de 5 ocorrer, o laço de repetição deve avançar para a próxima iteração.

# %%
i = 0
while i < 100:
  i += 1
  if i % 5 == 0:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19
# 21
# 22
# 23
# 24
# 26
# 27
# 28
# 29
# 31
# 32
# 33
# 34
# 36
# 37
# 38
# 39
# 41
# 42
# 43
# 44
# 46
# 47
# 48
# 49
# 51
# 52
# 53
# 54
# 56
# 57
# 58
# 59
# 61
# 62
# 63
# 64
# 66
# 67
# 68
# 69
# 71
# 72
# 73
# 74
# 76
# 77
# 78
# 79
# 81
# 82
# 83
# 84
# 86
# 87
# 88
# 89
# 91
# 92
# 93
# 94
# 96
# 97
# 98
# 99

# %% [markdown]
# ##Repetição com sentinela
#
# Sentinela é um valor que indica o final de uma sequência de dados. Enquanto este valor da sequência não for atingido, repete-se o bloco de comandos.
#
# Assim, a quantidade de iterações fica dependente de uma condição envolvendo o valor sentinela. Ou seja, não se conhece, antecipadamente, quando irá surgir o valor sentinela na sequência de dados de entrada.

# %%
# usando o valor -1 como sentinela:

valor = 1 # inicializa com um valor qualquer, apenas para criar a variável
while valor != -1:
  valor = int(input("Digite um valor ou (-1) para encerrar: "))
  print(f"Você digitou {valor}")

# %% [markdown]
# No interior do bloco de comandos do `while`, é possível usar uma estrutura de decisão para distinguir quando o valor é ou não o sentinela e, assim, tratar cada caso de uma forma diferente:

# %%
# usando o valor -1 como sentinela:

valor = 1 # inicializa com um valor qualquer, apenas para criar a variável
cont = 0  # para contar o número de valores digitados
while valor != -1:
  valor = int(input("Digite um valor positivo ou (-1) para encerrar: "))
  if valor == -1:
    print("O programa será encerrado")
  else:
    print(f"Você digitou {valor}")  
    cont = cont + 1
print(f"Foram digitados {cont} valores válidos")

# %% [markdown]
# Outra forma de trabalhar com sentinela é criar um `loop infinito`, que será quebrado (`break`) quando o valor sentinela for obtido:

# %%
while True:
  valor = int(input("Digite um valor ou (-1) para encerrar: "))
  print(f"Você digitou {valor}")
  if valor == -1:
    print("O programa será encerrado")
    break

# %% [markdown]
# O sentinela também pode ser uma faixa de valores, como por exemplo, qualquer número negativo:

# %%
while True:
  valor = int(input("Digite um valor positivo para prosseguir ou um valor negativo para encerrar: "))
  print(f"Você digitou {valor}")
  if valor < 0:
    print("Você digitou um valor negativo. O programa será encerrado")
    break

# %% [markdown]
# ###Atividades
#
# **AT7** - Faça um programa que leia N números (um por vez) enquanto o usuário digitar um valor diferente de zero. Após, imprima na tela qual foi o maior número digitado.
#
# Exemplo de entrada:
#
# 5
#
# 9
#
# 29
#
# 4
#
# 0
#
# Saida: O maior valor é: 29

# %%
n2 = int(input('Digite um valor para comparação: '))
while True:
  n1 = int(input('Digite outro valor para comparação, insira "0" caso não haja mais valores. '))
  if n1 == 0:
    break
  if n2 < n1:
    n2 = n1
print(f'O maior valor inserido é: {n2}')
# Out:
# Digite um valor para comparação: 8
# Digite outro valor para comparação, insira "0" caso não haja mais valores. 6
# Digite outro valor para comparação, insira "0" caso não haja mais valores. 1
# Digite outro valor para comparação, insira "0" caso não haja mais valores. 8
# Digite outro valor para comparação, insira "0" caso não haja mais valores. 41
# Digite outro valor para comparação, insira "0" caso não haja mais valores. -41
# Digite outro valor para comparação, insira "0" caso não haja mais valores. 0
# O maior valor inserido é: 41

# %% [markdown]
# **AT8** - Faça um código que leia indefinidamente um valor informado pelo usuário e calcule os impostos em 10% do valor informado. O código só irá finalizar quando o usuário digitar o valor -1. Fazer usando o comando break.

# %%
valor = float(input("Digite um valor: "))
while True:
  while valor > 0:
    valor = (valor * 0.1) + valor
    print(f'O valor com juros de 10% é: {valor:.2f}')
    valor = float(input("Digite um novo valor (Ou -1 caso queira sair): "))
  break
# Out:
# Digite um valor: 8472
# O valor com juros de 10% é: 9319.20
# Digite um novo valor (Ou -1 caso queira sair): 47
# O valor com juros de 10% é: 51.70
# Digite um novo valor (Ou -1 caso queira sair): 895
# O valor com juros de 10% é: 984.50
# Digite um novo valor (Ou -1 caso queira sair): 7489
# O valor com juros de 10% é: 8237.90
# Digite um novo valor (Ou -1 caso queira sair): 74824125
# O valor com juros de 10% é: 82306537.50
# Digite um novo valor (Ou -1 caso queira sair): -8

# %% [markdown]
# **AT9** - Faça um programa que leia um conjunto de notas de alunos e, ao final, mostre a média geral da turma. A entrada será finalizada quando for lida a nota 999.

# %%
nota1 = float(input('Digite a nota do aluno: '))
cont = 1
while True:
  nota2 = float (input('Digite a nota do aluno (999 para encerrar): '))
  if nota2 == 999:
    break
  cont += 1
  nota1 = nota1 + nota2
print(f'A média geral da turma é {(nota1 / cont):.2f}')
# Out:
# Digite a nota do aluno: 6
# Digite a nota do aluno (999 para encerrar): 7
# Digite a nota do aluno (999 para encerrar): 8
# Digite a nota do aluno (999 para encerrar): 999
# A média geral da turma é 7.00

# %% [markdown]
# **AT10** - O comando while também pode ser utilizado para validar uma entrada de dados, isto é, caso o usuário digite um valor fora do intervalo esperado, o programa continua solicitando a digitação do valor até que um valor válido seja informado.
#
# Faça um programa que leia a idade de uma pessoa e a classifique em menor ou maior de idade. Antes de passar para a classificação, deve ser verificado se a idade está no intervalo entre 0 e 120. Em caso negativo, o programa deve repetir o input até que um valor dentro deste intervalo seja digitado.

# %%
idade = int(input('Digite sua idade ( 0 a 120): '))
while idade > 120 or idade < 0:
  idade = int(input('Digite uma idade válida (0 a 120): '))
if idade >= 18:
  print('Maior de idade')
else:
  print('Menor de idade')
# Out:
# Digite sua idade ( 0 a 120): 121
# Digite uma idade válida (0 a 120): 125
# Digite uma idade válida (0 a 120): -655
# Digite uma idade válida (0 a 120): 165
# Digite uma idade válida (0 a 120): 56
# Maior de idade

# %% [markdown]
# #Repetições encadeadas
#
# A estrutura de repetição While pode ser encadeada, ou seja, podemos ter uma repetição aninhada dentro de outra repetição.
#
# Quando isso ocorre, para toda iteração do laço de repetição mais externo, são executadas todas as repetições do laço mais interno. Veja os exemplos abaixo:

# %%
i = 0
while(i < 4):
  print(f"i está valendo: {i}")
  j = 0
  while(j < 5):
    print(f"\tj está valendo: {j}") # \t = tabulação
    j += 1
  i += 1
print("fim do programa")

# %% [markdown]
# Vamos desenhar um quadrado de asteriscos usando while:

# %%
lin = 1
while lin <= 10:
  col = 1
  while col <= 10:
    print("*", end=' ')  # o parâmetro end indica o finalizador de linha
    col += 1
  print()  
  lin += 1
